# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavisklm/rgukt/blob/main/DSP_Map_path_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
map=folium.Map(location=[16.7850, 80.8488],tiles='cartodbpositron',zoom_start=8,zoom_en=14)
coordinates_1=[[16.78644892718052, 80.84769213532057],[16.777245299680562, 80.8779045367455],[16.786448927180505, 80.95137560683638],
               [16.75357678272117, 81.02759325289634],[16.736481022887073, 81.06741869113831],[16.83640368943539, 81.53021774932942],
               [16.7512755200826, 81.7403312750542],[16.654597396863142, 81.7430778606981],[16.518376090607443, 81.72453843255097]]
coordinates_2=[[16.785660475896055, 80.84631884413781],[16.67650265274154, 80.94794237620353],[16.688013199832405, 80.99120103580343],
               [16.686040012348307, 81.00699388200283],[16.689328646837808, 81.0241600191761],[16.784016997248035, 81.22260056819827],
               [16.810310954672065, 81.31598435442082],[16.824771078359117, 81.46017991350469],[16.80768172293667, 81.53021775475861],
               [16.713662783343615, 81.53983079157565],[16.636703710572796, 81.65930710991411],[16.538651286914998, 81.62772141751533],
               [16.519561454219133, 81.70187913010382],[16.518244844470367, 81.72522507665946]]

              
#creating feature groups

f1=folium.FeatureGroup("path1")
f2=folium.FeatureGroup("path2")
folium.Marker(location=[16.75357678272117, 81.02759325289634],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='glyphicon',icon='off')).add_to(map)
folium.Marker(location=[16.7512755200826, 81.7403312750542],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='ambulance')).add_to(map)
folium.Marker(location=[16.824771078359117, 81.46017991350469],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='green',prefix='fa',icon='gasstation')).add_to(map)
folium.Marker(location=[16.713662783343615, 81.53983079157565],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='voilet',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[16.538651286914998, 81.62772141751533],popup='Default popup Marker1',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[16.519561454219133, 81.70187913010382],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='Golfing')).add_to(map)
folium.Marker(location=[16.518244844470367, 81.72522507665946],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='hospital-o')).add_to(map)
folium.Marker(location=[16.654597396863142, 81.7430778606981],popup='Default popup Marker1',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='none')).add_to(map)
folium.Marker(location=[16.636703710572796, 81.65930710991411],popup='<strong>Marker3</strong>',tooltip='<strong>Click here to see Popup</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='Airport')).add_to(map)
folium.Marker(location=[16.736481022887073, 81.06741869113831],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Click here to see Guntur</strong>',icon=folium.Icon(color='hotpink',prefix='fa',icon='ambulance')).add_to(map)


#adding lines to the different feature groups
line_1=folium.vector_layers.PolyLine(coordinates_1,popup='<b>path to palakol_1</b>',tooltip='path1',color='red',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(coordinates_2,popup='<b>path to palakol_2</b>',tooltip='path2',color='blue',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: color argument of Icon should be one of: {'orange', 'black', 'darkred', 'lightgray', 'darkgreen', 'cadetblue', 'red', 'darkpurple', 'lightgreen', 'beige', 'purple', 'white', 'green', 'pink', 'blue', 'lightred', 'lightblue', 'gray', 'darkblue'}.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: UserWarning: color argument of Icon should be one of: {'orange', 'black', 'darkred', 'lightgray', 'darkgreen', 'cadetblue', 'red', 'darkpurple', 'lightgreen', 'beige', 'purple', 'white', 'green', 'pink', 'blue', 'lightred', 'lightblue', 'gray', 'darkblue'}.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
# ...
